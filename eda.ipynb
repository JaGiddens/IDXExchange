# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

# %%
df = pd.read_csv("CRMLSListing202602.csv")
# Out:
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0           630000.0  1155889366         NaN         NaN              James
# 1          1099000.0  1155889183         NaN         NaN             Bailey
# 2           499000.0  1155888472         NaN         NaN             Edward
# 3          2000000.0  1155888254         NaN         NaN               Mary
# 4          2250000.0  1155888060  2026-03-25   2250000.0               Jeff
#
#   ListAgentLastName   Latitude   Longitude            UnparsedAddress  \
# 0              Tran  33.966301 -117.238653           10625 Aster Leaf
# 1              Tarr  32.897005 -117.167538          10423 Adamson Way
# 2          Kaminsky  33.831316 -118.376615  641 S Prospect Avenue 103
# 3              Bell  33.777977 -117.798519               19151 Fowler
# 4        McConville  33.634020 -117.909194                1809 Tustin
#
#   PropertyType  ...  MainLevelBedrooms  NewConstructionYN  GarageSpaces  \
# ...

# %%
df.shape
# Out:
# (32353, 81)

# %%
df.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'CloseDate', 'ClosePrice',
#        'ListAgentFirstName', 'ListAgentLastName', 'Latitude', 'Longitude',
#        'UnparsedAddress', 'PropertyType', 'LivingArea', 'ListPrice',
#        'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'PropertyType.1', 'MlsStatus', 'ElementarySchool',
#        'ListAgentFirstName.1', 'AttachedGarageYN', 'ParkingTotal',
#        'BuilderName', 'PropertySubType', 'LotSizeAcres', 'SubdivisionName',
#        'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1', 'StreetNumberNumeric',
#        'LivingArea.1', 'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
# ...

# %%
df.describe()
# Out:
#        OriginalListPrice    ListingKey    ClosePrice      Latitude  \
# count       3.221900e+04  3.235300e+04  6.540000e+03  31875.000000
# mean        1.121162e+06  1.153098e+09  7.737355e+05     34.566048
# std         7.180938e+06  8.464752e+05  1.212817e+06      1.655698
# min         1.000000e+00  1.063377e+09  1.770000e+00      0.000000
# 25%         1.300000e+05  1.152613e+09  4.295000e+03     33.760202
# 50%         6.499000e+05  1.153092e+09  5.350000e+05     34.056781
# 75%         1.198000e+06  1.153435e+09  1.100000e+06     34.431280
# max         8.195000e+08  1.155889e+09  3.026000e+07     41.891615
#
#           Longitude    LivingArea     ListPrice  DaysOnMarket  \
# count  31887.000000  27994.000000  3.226200e+04  32353.000000
# mean    -118.427221   1935.097253  1.033634e+06     16.372114
# std        3.597770   1612.617770  2.251182e+06     15.750910
# min     -155.633577      0.000000  1.000000e+00    -17.000000
# ...

# %%
df.isna().sum()
# Out:
# OriginalListPrice                 134
# ListingKey                          0
# CloseDate                       24905
# ClosePrice                      25813
# ListAgentFirstName                167
#                                 ...
# BuyerOfficeName.1               25229
# AssociationFee                   9874
# LotSizeSquareFeet                2791
# MiddleOrJuniorSchoolDistrict    32353
# UnparsedAddress.1                  67
# Length: 81, dtype: int64

# %%
df.dtypes
# Out:
# OriginalListPrice               float64
# ListingKey                        int64
# CloseDate                        object
# ClosePrice                      float64
# ListAgentFirstName               object
#                                  ...
# BuyerOfficeName.1                object
# AssociationFee                  float64
# LotSizeSquareFeet               float64
# MiddleOrJuniorSchoolDistrict    float64
# UnparsedAddress.1                object
# Length: 81, dtype: object

# %%
# check for duplicates
df1 = df.copy()
dupes = [col for col in df1.columns if f"{col}.1" in df1.columns] # duplicates have .1 in name
{col: df1[col].equals(df1[f"{col}.1"]) for col in dupes} # see if they are identical
# Out:
# {'CloseDate': True,
#  'ListAgentFirstName': True,
#  'ListAgentLastName': True,
#  'Latitude': True,
#  'Longitude': True,
#  'UnparsedAddress': True,
#  'PropertyType': True,
#  'LivingArea': True,
#  'ListPrice': True,
#  'DaysOnMarket': True,
#  'BuyerOfficeName': True}

# %%
# drop duplicates
df1 = df1.drop(columns=[f"{col}.1" for col in dupes])

# check again
dupes = [col for col in df1.columns if f"{col}.1" in df1.columns]
{col: df1[col].equals(df1[f"{col}.1"]) for col in dupes}
# Out:
# {}

# %%
print("original shape:", (df.shape))
print("modified shape:", (df1.shape))
# Out:
# original shape: (32353, 81)
# modified shape: (32353, 70)

# %%
# percent of non na values for date cols
dates = [col for col in df1.columns if col.endswith('Date')]
{col: f"{round(100*((df1.shape[0] - df1[col].isna().sum())/df1.shape[0]))}%" for col in dates}
# Out:
# {'CloseDate': '23%',
#  'ContractStatusChangeDate': '99%',
#  'PurchaseContractDate': '42%',
#  'ListingContractDate': '100%'}

# %%
# check data types for dates
df1[dates].dtypes
# Out:
# CloseDate                   object
# ContractStatusChangeDate    object
# PurchaseContractDate        object
# ListingContractDate         object
# dtype: object

# %%
df1[dates].head()
# Out:
#     CloseDate ContractStatusChangeDate PurchaseContractDate  \
# 0         NaN               2026-02-24                  NaN
# 1         NaN               2026-03-28                  NaN
# 2         NaN               2026-02-17                  NaN
# 3         NaN               2026-02-25                  NaN
# 4  2026-03-25               2026-03-25           2026-02-08
#
#   ListingContractDate
# 0          2026-02-24
# 1          2026-02-25
# 2          2026-02-17
# 3          2026-02-25
# 4          2026-02-08

# %%
# change to datetime type
df1[dates] = df1[dates].apply(pd.to_datetime)

# check change
df1[dates].dtypes
# Out:
# CloseDate                   datetime64[ns]
# ContractStatusChangeDate    datetime64[ns]
# PurchaseContractDate        datetime64[ns]
# ListingContractDate         datetime64[ns]
# dtype: object

# %%
# check cols that have too many na values -> consider dropping them
cols_with_many_na = df1.columns[df1.isna().sum() >= 15000]
print(cols_with_many_na)
df1[cols_with_many_na]
# Out:
# Index(['CloseDate', 'ClosePrice', 'BuyerOfficeName', 'CoListOfficeName',
#        'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId',
#        'BuyerAgentFirstName', 'BuyerAgentLastName', 'FireplacesTotal',
#        'AssociationFeeFrequency', 'AboveGradeFinishedArea', 'TaxAnnualAmount',
#        'ElementarySchool', 'BuilderName', 'SubdivisionName', 'BuyerOfficeAOR',
#        'TaxYear', 'BuildingAreaTotal', 'ElementarySchoolDistrict',
#        'CoBuyerAgentFirstName', 'PurchaseContractDate',
#        'BelowGradeFinishedArea', 'BusinessType', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'HighSchool', 'LotSizeDimensions',
#        'MainLevelBedrooms', 'MiddleOrJuniorSchoolDistrict'],
#       dtype='object')
# Number of cols : 40
#        CloseDate  ClosePrice                BuyerOfficeName  \
# 0            NaT         NaN                            NaN
# 1            NaT         NaN                            NaN
# ...

# %%
df2 = df1.drop(columns=cols_with_many_na)

# %%
df2.head()
# Out:
#    OriginalListPrice  ListingKey ListAgentFirstName ListAgentLastName  \
# 0           630000.0  1155889366              James              Tran
# 1          1099000.0  1155889183             Bailey              Tarr
# 2           499000.0  1155888472             Edward          Kaminsky
# 3          2000000.0  1155888254               Mary              Bell
# 4          2250000.0  1155888060               Jeff        McConville
#
#     Latitude   Longitude            UnparsedAddress PropertyType  LivingArea  \
# 0  33.966301 -117.238653           10625 Aster Leaf  Residential      2109.0
# 1  32.897005 -117.167538          10423 Adamson Way  Residential      1686.0
# 2  33.831316 -118.376615  641 S Prospect Avenue 103  Residential       748.0
# 3  33.777977 -117.798519               19151 Fowler  Residential      4278.0
# 4  33.634020 -117.909194                1809 Tustin  Residential      2056.0
#
#    ListPrice  ...  FireplaceYN Stories                  Levels  LotSizeArea  \
# ...

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (32353, 70)
# (32353, 40)

# %%
# cols with no na 
cols_with_no_na = df1.columns[df1.isna().sum() == 0]
cols_with_no_na.to_list()
df2[cols_with_no_na]
# Out:
#        ListingKey      PropertyType  DaysOnMarket  \
# 0      1155889366       Residential             0
# 1      1155889183       Residential             0
# 2      1155888472       Residential             0
# 3      1155888254       Residential             0
# 4      1155888060       Residential             0
# ...           ...               ...           ...
# 32348  1149458718  ResidentialLease            15
# 32349  1146439434  ResidentialLease            38
# 32350  1146104836       Residential            76
# 32351  1107246684  ResidentialLease           359
# 32352  1063377179  ResidentialLease           710
#
#                        ListOfficeName  ListingKeyNumeric CountyOrParish  \
# 0                  A-Med Realty Group         1155889366      Riverside
# 1                 The Oppenheim Group         1155889183      San Diego
# 2       eXp Realty of California, Inc         1155888472    Los Angeles
# ...

# %%
# check number of uniqe values no na
{col : len(df2[col].unique()) for col in cols_with_no_na}
# Out:
# {'ListingKey': 32353,
#  'PropertyType': 8,
#  'DaysOnMarket': 104,
#  'ListOfficeName': 6347,
#  'ListingKeyNumeric': 32353,
#  'CountyOrParish': 59,
#  'MlsStatus': 5,
#  'ListingId': 32353,
#  'ListingContractDate': 28}

# %% [markdown]
# We can see that ListingKey, ListingKeyNumeric and ListingId are unique values

# %%
print(df2['ListingKey'].equals(df2['ListingKeyNumeric']))
df2[['ListingKey', 'ListingKeyNumeric']].dtypes
# Out:
# True
# ListingKey           int64
# ListingKeyNumeric    int64
# dtype: object

# %%
# check for more duplicates - numeric
numerics = [col for col in df1.columns if col.endswith('Numeric')]
numerics
# Out:
# ['ListingKeyNumeric', 'StreetNumberNumeric']

# %%
# drop only ListingKeyNumeric, b/c there is only one streetNumber
df2 = df2.drop(columns='ListingKeyNumeric')
